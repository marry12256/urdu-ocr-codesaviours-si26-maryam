# %% [markdown]
# <a href="https://colab.research.google.com/github/marry12256/urdu-ocr-codesaviours-si26-maryam/blob/main/SI26_week1_maryam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What is OCR (Optical Character Recognition)?
#
# OCR (Optical Character Recognition) is a technology that converts text from images, scanned documents, or photos into editable and searchable digital text. It helps computers recognize printed or handwritten characters automatically. OCR saves time because people do not have to type the text manually.
#
# 2. Why is Urdu OCR harder than English OCR?
#
# Urdu OCR is more difficult than English OCR because Urdu is written from right to left and its letters change shape depending on their position in a word. Many Urdu letters look very similar and are distinguished only by dots, making them harder for computers to recognize accurately. In addition, connected writing styles and different fonts increase the complexity of Urdu OCR.
#
# 3. What are 2 real-world situations where Urdu OCR would be useful?
#
# One useful application of Urdu OCR is digitizing old Urdu books, newspapers, and historical documents so they can be searched and preserved electronically. Another application is extracting text from printed forms, bills, or government documents, allowing organizations to store and process information more efficiently. These uses reduce manual data entry, save time, and improve access to Urdu-language information.

# %%
# !pip install Pillow arabic-reshaper python-bidi
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Collecting arabic-reshaper
#   Downloading arabic_reshaper-3.0.1-py3-none-any.whl.metadata (13 kB)
# Collecting python-bidi
#   Downloading python_bidi-0.6.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.3 kB)
# Downloading arabic_reshaper-3.0.1-py3-none-any.whl (20 kB)
# Downloading python_bidi-0.6.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.2/296.2 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: python-bidi, arabic-reshaper
# Successfully installed arabic-reshaper-3.0.1 python-bidi-0.6.11

# %%
# !wget -O NotoNaskhArabic-Regular.ttf https://github.com/googlefonts/noto-fonts/raw/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf
# Out:
# --2026-07-19 14:51:28--  https://github.com/googlefonts/noto-fonts/raw/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/notofonts/noto-fonts/raw/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf [following]
# --2026-07-19 14:51:28--  https://github.com/notofonts/noto-fonts/raw/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/notofonts/noto-fonts/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf [following]
# --2026-07-19 14:51:28--  https://raw.githubusercontent.com/notofonts/noto-fonts/main/hinted/ttf/NotoNaskhArabic/NotoNaskhArabic-Regular.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 178388 (174K) [application/octet-stream]
# Saving to: ‘NotoNaskhArabic-Regular.ttf’
#
# NotoNaskhArabic-Reg 100%[===================>] 174.21K  --.-KB/s    in 0.02s
#
# 2026-07-19 14:51:28 (9.63 MB/s) - ‘NotoNaskhArabic-Regular.ttf’ saved [178388/178388]

# %%
from PIL import Image, ImageDraw, ImageFont
import arabic_reshaper
from bidi.algorithm import get_display
import os

urdu_texts = [
    "\u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u0632\u0646\u062f\u06c1 \u0628\u0627\u062f",
    "\u0622\u062c \u06a9\u0627 \u0645\u0648\u0633\u0645 \u062e\u0648\u0634\u06af\u0648\u0627\u0631 \u06c1\u06d2",
    "\u062a\u0639\u0644\u06cc\u0645 \u06c1\u0631 \u0627\u0646\u0633\u0627\u0646 \u06a9\u0627 \u062d\u0642 \u06c1\u06d2",
    "\u06a9\u0631\u0627\u0686\u06cc \u067e\u0627\u06a9\u0633\u062a\u0627\u0646 \u06a9\u0627 \u0633\u0628 \u0633\u06d2 \u0628\u0691\u0627 \u0634\u06c1\u0631 \u06c1\u06d2",
    "\u0645\u062d\u0646\u062a \u06a9\u0627\u0645\u06cc\u0627\u0628\u06cc \u06a9\u06cc \u06a9\u0646\u062c\u06cc \u06c1\u06d2",

    "\u0627\u0631\u062f\u0648 \u06c1\u0645\u0627\u0631\u06cc \u0642\u0648\u0645\u06cc \u0632\u0628\u0627\u0646 \u06c1\u06d2",

    "\u06c1\u0645 \u0631\u0648\u0632\u0627\u0646\u06c1 \u0645\u0637\u0627\u0644\u0639\u06c1 \u06a9\u0631\u062a\u06d2 \u06c1\u06cc\u06ba"
]

os.makedirs("data/synthetic", exist_ok=True)

font = ImageFont.truetype("NotoNaskhArabic-Regular.ttf", 40)

for i, text in enumerate(urdu_texts):

    reshaped = arabic_reshaper.reshape(text)


    img = Image.new("RGB", (700, 100), "white")
    draw = ImageDraw.Draw(img)

    draw.text((20, 30), reshaped, font=font, fill="black")
    img.save(f"data/synthetic/urdu_{i+1}.png")
    print(f"Generated: urdu_{i+1}.png")

print("Done!")
# Out:
# Generated: urdu_1.png
# Generated: urdu_2.png
# Generated: urdu_3.png
# Generated: urdu_4.png
# Generated: urdu_5.png
# Generated: urdu_6.png
# Generated: urdu_7.png
# Done!

# %%
import os

folders = [
    "data/raw/newspaper",
    "data/raw/books",
    "data/raw/signboards",
    "data/raw/synthetic",
    "data/raw/other"
    'data/raw/one',
    'data/raw/two',
    'data/raw/three',
    'data/raw/four',
    'data/raw/five'
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

print("Folder structure ready!")
# Out:
# Created: data/raw/newspaper
# Created: data/raw/books
# Created: data/raw/signboards
# Created: data/raw/synthetic
# Created: data/raw/otherdata/raw/one
# Created: data/raw/two
# Created: data/raw/three
# Created: data/raw/four
# Created: data/raw/five
# Folder structure ready!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

labels = [

    {'image': 'data/raw/newspaper/textbox_32_line_2_.png',
     'text': 'کمرے کل بنے گا، انہیں مفت میں جانے دی گئی'},
    {'image': 'data/raw/newspaper/textbox_33_line_1_.png',
     'text': 'ہوٹل میں کھانا کھلا ہے۔ کھانا اچھا ہے۔ سٹاف کا'},
    {'image': 'data/raw/newspaper/textbox_33_line_2_.png',
     'text': 'لوگ دو ستارے ہیں۔ کمرے صاف اور روشن ہیں۔'},
    {'image': 'data/raw/newspaper/textbox_34_line_2_.png',
     'text': 'ہوٹل کا سٹاف اچھا میں ہے۔ ہمیں بہت انتظار'},
    {'image': 'data/raw/newspaper/textbox_34_line_3_.png',
     'text': 'کروایا۔ میں دوبارہ اس ہوٹل میں نہیں آؤں گا۔'},
    {'image': 'data/raw/newspaper/textbox_35_line_1_.png',
     'text': 'میں نے ہوٹل میں دو کمروں کی بکنگ کروائی'},
    {'image': 'data/raw/newspaper/textbox_35_line_2_.png',
     'text': 'ہوٹل آکر مجھے صرف ایک کمرہ دیا گیا۔'},
    {'image': 'data/raw/newspaper/textbox_36_line_1_.png',
     'text': 'ہوٹل دیکھنے میں بہت خوبصورت ہے۔ ہوٹل کا'},
    {'image': 'data/raw/newspaper/textbox_36_line_2_.png',
     'text': 'احاطہ کافی بڑا ہے۔ ہوٹل کا کھانا لذیذ ہے۔'},
    {'image': 'data/raw/newspaper/textbox_37_line_1_.png',
     'text': 'ہوٹل کا کھانا مزیدار'},
    {'image': 'data/raw/newspaper/textbox_37_line_2_.png',
     'text': 'صحیح تھا۔ ہوٹل کا ماحول خوشگوار تھا۔'},
    {'image': 'data/raw/newspaper/textbox_38_line_1_.png',
     'text': 'ہوٹل کی پارکنگ بہت بڑی ہے۔ ہوٹل کی سیکیورٹی'},
    {'image': 'data/raw/newspaper/textbox_38_line_2_.png',
     'text': 'کا نظام اچھا ہے۔ ہوٹل کا کھانا عمدہ ہے۔'},
    {'image': 'data/raw/newspaper/urdu_1.png',
     'text': 'پاکستان زندہ باد'},
    {'image': 'data/raw/newspaper/urdu_2.png',
     'text': 'آج کا موسم خوشگوار ہے'},
    {'image': 'data/raw/newspaper/urdu_3.png',
     'text': 'تعلیم ہر انسان کا حق ہے'},
    {'image': 'data/raw/newspaper/urdu_4.png',
     'text': 'کراچی پاکستان کا سب سے بڑا شہر ہے'},
    {'image': 'data/raw/newspaper/urdu_5.png',
     'text': 'محنت کامیابی کی کنجی ہے'},
    {'image': 'data/raw/newspaper/urdu_6.png',
     'text': 'اردو ہماری قومی زبان ہے'},
    {'image': 'data/raw/newspaper/urdu_7.png',
     'text': 'ہم روزانہ مطالعہ کرتے ہیں'},

     {'image': 'data/raw/newspaper/news1_jpg.jpeg',
     'text': "غیر ملکی خبر رساں ادارے 'اے ایف پی' کی رپورٹ کے"},
    {'image': 'data/raw/newspaper/news10_jpg.jpeg',
     'text': 'سرپرستی میں منعقدہ ایک ثقافتی تقریب کے دوران'},
    {'image': 'data/raw/newspaper/news11_jpg.jpeg',
     'text': 'کراچی (نیوز ڈیسک) پاکستان نے اپنی سب سے بڑی فعال چینی'},
    {'image': 'data/raw/newspaper/news12_jpg.jpeg',
     'text': 'چین نے بھارتی وزارت خارجہ کے کشمیر کی وادی'},
    {'image': 'data/raw/newspaper/news2_jpg.jpeg',
     'text': 'اسلام آباد میں ہفتہ وار بریفنگ کے دوران طاہر اندرابی سے'},
    {'image': 'data/raw/newspaper/news3_jpg.jpeg',
     'text': 'وانگچک کی بھوک ہڑتال کا انّا ہزارے سے موازنہ'},
    {'image': 'data/raw/newspaper/news4_jpg.jpeg',
     'text': 'انڈیا کے زیر انتظام علاقے لداخ سے تعلق رکھنے والے سماجی'},
    {'image': 'data/raw/newspaper/news5_jpg.jpeg',
     'text': 'مصنوعی قلت پیدا کرنے والوں کے خلاف سخت کارروائی کی'},
    {'image': 'data/raw/newspaper/news6_jpg.jpeg',
     'text': 'ایک مثبت قدم ہے جسے آگے بڑھایا جانا چاہیے۔'},
    {'image': 'data/raw/newspaper/news7_jpg.jpeg',
     'text': 'آگے بڑھنے سے پہلے ہم اس بات کو سراہتے ہیں کہ ایچ'},
    {'image': 'data/raw/newspaper/news8_jpg.jpeg',
     'text': 'اقدامات اور محاذ جنگ پر کارکردگی کا تجزیہ اور بہتری لانے'},
    {'image': 'data/raw/newspaper/news9_jpg.jpeg',
     'text': 'ہر ممکن سہولیات فراہم کرے،تفصیلات کے مطابق وزیراعظم کی'},

    {'image': 'data/raw/newspaper/textbox_10_line_1_.png',
     'text': 'میں نے دو دن پہلے کمرہ بک کروایا تھا۔ پھر بھی ہوٹل'},
    {'image': 'data/raw/newspaper/textbox_10_line_2_.png',
     'text': 'والوں نے انتظار کروایا۔'},
    {'image': 'data/raw/newspaper/textbox_11_line_1_.png',
     'text': 'ہوٹل سٹاف دوستانہ ہے، ہوٹل کے کمرے کی'},
    {'image': 'data/raw/newspaper/textbox_11_line_2_.png',
     'text': 'کھڑکی روشن اور بڑی ہے۔ میں دوبارہ آؤں گا۔'},
    {'image': 'data/raw/newspaper/textbox_12_line_2_.png',
     'text': 'ہوٹل کا عملہ غیر موجود ہے۔ ہوٹل میں کوئی بات'},
    {'image': 'data/raw/newspaper/textbox_12_line_3_.png',
     'text': 'سننے والا نہیں ہے۔ ہوٹل کی سروس بہت بہتری ہے۔'},
    {'image': 'data/raw/newspaper/textbox_13_line_1_.png',
     'text': 'ہوٹل منیجر کا سلوک بہترین تھا۔ صبح کا ناشتہ مفت'},
    {'image': 'data/raw/newspaper/textbox_13_line_2_.png',
     'text': 'تھا۔ میں اس ہوٹل میں دوبارہ ضرور آؤں گا۔'},


    {'image': 'data/raw/newspaper/textbox_14_line_1_.png',
     'text': 'ہوٹل کا عملہ غیر حاضر تھا۔ ہوٹل کے برعکس'},
    {'image': 'data/raw/newspaper/textbox_14_line_2_.png',
     'text': 'کمرے اور صاف ستھرے تھے۔ کھانا اچھا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_15_line_2_.png',
     'text': 'ہوٹل کے کمرے کی صفائی کا خاص خیال رکھا گیا'},
    {'image': 'data/raw/newspaper/textbox_15_line_3_.png',
     'text': 'ہوٹل کا سٹاف نہایت خوشگوار ہے۔'},
    {'image': 'data/raw/newspaper/textbox_16_line_1_.png',
     'text': 'ہوٹل کا عملہ کافی دوستانہ ہے۔ ہوٹل سے'},
    {'image': 'data/raw/newspaper/textbox_16_line_2_.png',
     'text': 'کھیل کا منظر خوبصورت نظر آتا ہے۔'},
    {'image': 'data/raw/newspaper/textbox_17_line_1_.png',
     'text': 'ہوٹل کا کھانا مزیدار تھا اور یہ منظر کا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_17_line_2_.png',
     'text': 'ہوٹل کا سٹاف خوش شکل اور دوستانہ تھا۔'},
    {'image': 'data/raw/newspaper/textbox_18_line_1_.png',
     'text': 'صبح کے وقت باتھ روم میں گرم پانی نہیں آ رہا تھا۔'},
    {'image': 'data/raw/newspaper/textbox_18_line_2_.png',
     'text': 'میں نے گرم پانی کے لیے ہوٹل کا ریسیپٹ زیادہ دیا۔'},
    {'image': 'data/raw/newspaper/textbox_19_line_1_.png',
     'text': 'ہوٹل کا سٹاف اور عملہ نہایت دوستانہ ہے'},
    {'image': 'data/raw/newspaper/textbox_19_line_2_.png',
     'text': 'مجھے ہر قسم کی سہولت فراہم کی گئی۔'},
    {'image': 'data/raw/newspaper/textbox_20_line_1_.png',
     'text': 'ہوٹل جمیل کنارے واقع ہے۔ ہوٹل کا منظر'},
    {'image': 'data/raw/newspaper/textbox_20_line_2_.png',
     'text': 'خوبصورت ہے۔ ہوٹل سٹاف کا رویہ اچھا ہے۔'},
    {'image': 'data/raw/newspaper/textbox_21_line_1_.png',
     'text': 'ہوٹل کا عملہ بہت اچھا تھا۔ ہوٹل صاف تھا۔ ہوٹل کا کمرہ'},
    {'image': 'data/raw/newspaper/textbox_21_line_2_.png',
     'text': 'کھلا اور روشن تھا۔ کمرے کی صفائی کا خاص خیال تھا۔'},
    {'image': 'data/raw/newspaper/textbox_22_line_1_.png',
     'text': 'میں نے دو دن پہلے بکنگ کروائی تھی۔ لیکن اس'},
    {'image': 'data/raw/newspaper/textbox_22_line_2_.png',
     'text': 'کے باوجود میرا کمرہ کسی اور کو دے دیا گیا۔'},
    {'image': 'data/raw/newspaper/textbox_23_line_1_.png',
     'text': 'ہوٹل کی سروس خراب تھی، نمایاں صفائی کا کوئی'},
    {'image': 'data/raw/newspaper/textbox_23_line_2_.png',
     'text': 'خیال نہیں۔ ہوٹل کے کمرے چھوٹے ہیں۔'},

      {'image': 'data/raw/newspaper/img001.jpg',
     'text': 'کوڑا دان میں کوڑا ڈالیے!'},
    {'image': 'data/raw/newspaper/img002.jpg',
     'text': 'آگے کھانے پینے کی جگہ ہے!'},
    {'image': 'data/raw/newspaper/img003.jpg',
     'text': 'آگے پٹرول پمپ ہے!'},
    {'image': 'data/raw/newspaper/img004.jpg',
     'text': 'ہوٹل کی کمرے میں کھلنے - صبح کے وقت گرم پانی'},
    {'image': 'data/raw/newspaper/img005.jpg',
     'text': 'میں آتا - ہوٹل کے کمرے تنگ ہیں'},
    {'image': 'data/raw/newspaper/img006.jpg',
     'text': 'ہوٹل میں مسئلہ موجود نہ تھا - ہوٹل کے کمرے روشن'},
    {'image': 'data/raw/newspaper/img007.jpg',
     'text': 'کمرے - ہوٹل میں گرم پانی نہیں تھا'},
    {'image': 'data/raw/newspaper/img008.jpg',
     'text': 'ہوٹل میں صفائی کا خاص خیال رکھا گیا ہے'},
    {'image': 'data/raw/newspaper/img009.jpg',
     'text': 'میری کوئی شکایت نہیں ہے - میں پھر آؤں گا'},
    {'image': 'data/raw/newspaper/img010.jpg',
     'text': 'شام کے وقت چائے کا آرڈر دیا تھا - لیکن چائے پھر'},
    {'image': 'data/raw/newspaper/img011.jpg',
     'text': 'کچھ نہ آئی - ہوٹل کا عملہ بہت اچھا ہے'},
    {'image': 'data/raw/newspaper/img012.jpg',
     'text': 'ہوٹل میں میری تمام ضروریات کا خیال رکھا'},
    {'image': 'data/raw/newspaper/img013.jpg',
     'text': 'کل ہوٹل کا سٹاف نہایت قابل اور اچھا ہے'},
    {'image': 'data/raw/newspaper/img014.jpg',
     'text': 'ہوٹل کی بلڈنگ کافی پرانی ہے - ہوٹل میں گرم'},
    {'image': 'data/raw/newspaper/img015.jpg',
     'text': 'پانی کی سہولت موجود نہیں ہے'},
    {'image': 'data/raw/newspaper/img016.jpg',
     'text': 'ہوٹل کا کھانا مزے کا تھا - کھانے کی مقدار کم تھی'},
    {'image': 'data/raw/newspaper/img017.jpg',
     'text': 'بھی پلائی گئی - سٹاف نہایت بہترین دوستانہ ہے'},
    {'image': 'data/raw/newspaper/img018.jpg',
     'text': 'ہوٹل کا واش روم نہیں تھا - صفائی کا کوئی خیال نہیں'},
    {'image': 'data/raw/newspaper/img019.jpg',
     'text': 'خیال نہیں رکھا گیا تھا - رینٹ بہت زیادہ ہے'},
    {'image': 'data/raw/newspaper/img020.jpg',
     'text': 'ہوٹل کا عملہ دوستانہ ہے - ہمارا سامان گاڑی سے'},

       {'image': 'data/raw/newspaper/img021.jpg',
     'text': 'شاعری ادب کی اعلیٰ ترین صنف ہے'},
    {'image': 'data/raw/newspaper/img022.jpg',
     'text': 'کس طرح گزری۔ دلی سے لکھنؤ جاتے وقت جیں'},
    {'image': 'data/raw/newspaper/img023.jpg',
     'text': 'ہوٹل کا عملہ نہایت دوستانہ ہے۔ عملہ نے'},
    {'image': 'data/raw/newspaper/img024.jpg',
     'text': 'میری بہت مدد کی۔ میں یہاں ضرور واپس آؤں گا۔'},
    {'image': 'data/raw/newspaper/img025.jpg',
     'text': 'ہوٹل کی فضا خوشگوار ہے۔ ہوٹل کا ماحول'},
    {'image': 'data/raw/newspaper/img026.jpg',
     'text': 'خوشگوار ہے۔ ہوٹل کا عملہ دوستانہ ہے۔'},
    {'image': 'data/raw/newspaper/img027.jpg',
     'text': 'ہوٹل کا سٹاف اور عملہ نہایت اچھا اور دوستانہ'},
    {'image': 'data/raw/newspaper/img028.jpg',
     'text': 'ہے۔ ہوٹل کے کمرے صاف اور کھلے اور صاف ہے۔'},
    {'image': 'data/raw/newspaper/img029.jpg',
     'text': 'ہوٹل کی کمرے میں کھلتی۔ ہوٹل میں اچھے بستر'},
    {'image': 'data/raw/newspaper/img030.jpg',
     'text': 'تھیں یا۔ لیکن ہوٹل کا رینٹ بہت زیادہ ہے۔'},
    {'image': 'data/raw/newspaper/img031.jpg',
     'text': 'ہوٹل کے کمرے کے آدھے بلب جلتے میں تھے۔'},
    {'image': 'data/raw/newspaper/img032.jpg',
     'text': 'کمرے کا پنکھا بہت گرد آلود تھا۔'},
    {'image': 'data/raw/newspaper/img033.jpg',
     'text': 'ہوٹل کے واش روم گندے تھے۔ ہوٹل کی صفائی'},
    {'image': 'data/raw/newspaper/img034.jpg',
     'text': 'کا خیال نہیں رکھا گیا تھا۔ میں دوبارہ میں آؤں گا'},
    {'image': 'data/raw/newspaper/img035.jpg',
     'text': 'ہوٹل کی چائے کا ذائقہ حبیب تھا۔ چائے گرم نہیں تھی'},
    {'image': 'data/raw/newspaper/img036.jpg',
     'text': 'ہوٹل کا ڈینٹ صفائی سے ہے۔ ہوٹل ٹھیک ہے۔'},
    {'image': 'data/raw/newspaper/img037.jpg',
     'text': 'کل رات کافی شور ہوتا رہا۔ میں نے شکایت بھی کی'},
    {'image': 'data/raw/newspaper/img038.jpg',
     'text': 'لیکن کوئی سٹاف کمرے میں نہ آیا اور نہ مدد کی۔'},
    {'image': 'data/raw/newspaper/img039.jpg',
     'text': 'ہوٹل کے کمرے میں کوڑا پڑا ہوا تھا۔ کمرے میں'},
    {'image': 'data/raw/newspaper/img040.jpg',
     'text': 'سے بدبو آ رہی تھی۔ بیڈ پے کچرا پڑا ہوا تھا۔'},



    {'image': 'data/raw/synthetic/img001.jpg', 'text': 'اور بازار سے لے آئے اگر ٹوٹ گیا'},
    {'image': 'data/raw/synthetic/img002.jpg', 'text': 'گلزار اردو فونٹ'},
    {'image': 'data/raw/synthetic/img003.jpg', 'text': 'اب اپنے آپ سے بھی چھُپ گئی ہے'},
    {'image': 'data/raw/synthetic/img004.jpg', 'text': 'مہر تعلیق حالی خط'},
    {'image': 'data/raw/synthetic/img005.jpg', 'text': 'الصبور'},
    {'image': 'data/raw/synthetic/img006.jpg', 'text': 'ع'},
    {'image': 'data/raw/synthetic/img007.jpg', 'text': 'شاگرد'},
    {'image': 'data/raw/synthetic/img008.jpg', 'text': 'خواتین'},
    {'image': 'data/raw/synthetic/img009.jpg', 'text': 'خواجہ'},
    {'image': 'data/raw/synthetic/img010.jpg', 'text': 'الباقی'},
    {'image': 'data/raw/synthetic/img011.jpg', 'text': 'بتول'},
    {'image': 'data/raw/synthetic/img012.jpg', 'text': 'زبانِ اردو'},
    {'image': 'data/raw/synthetic/img013.jpg', 'text': 'میمن'},
    {'image': 'data/raw/synthetic/img014.jpg', 'text': 'صوف'},
    {'image': 'data/raw/synthetic/img015.jpg', 'text': 'دائرے میں گھومنے والوں کو کبھی منزل نہیں'},
    {'image': 'data/raw/newspaper/img016.jpg', 'text': 'اسرائیلی وزیر اعظم بنیامین نیتن یاہو نے عندیہ دیا ہے کہ وہ رواں سال نیویارک میں ہونے والے اقوام متحدہ کی جنرل اسمبلی کے اجلاس میں شرکت کریں گے۔'},
    {'image': 'data/raw/newspaper/img017.jpg', 'text': 'نیتن یاہو نے انٹرویو میں مزید کہا کہ وہ تمام نیویارک والوں کے میئر ہیں خواہ وہ یہودی ہوں،'},
    {'image': 'data/raw/newspaper/img018.jpg', 'text': 'سوموار کے روز ابراہیم عزیزی نے بیان میں کہا کہ یورپی یونین کی خارجہ پالیسی کی قیادت اور روسی وزیرِ خارجہ کے ساتھ گفتگو میں انہوں نے زور دیا کہ یوکرین کے اقدامات کا مناسب جواب دیا جائے گا۔'},
    {'image': 'data/raw/newspaper/img019.jpg', 'text': 'ایران کے ربر اعلی مجتبیٰ خامنہ ای نے واضح کیا ہے کہ لبنان کی علاقائی سالمیت کا تحفظ ایران، امریکہ مفاہمت کی پہلی شرط ہے'},
    {'image': 'data/raw/newspaper/img020.jpg', 'text': 'پیر کی صبح ہونے والی ٹریڈنگ میں تیل کی قیمتوں میں نمایاں کمی کا ریکارڈ کی گئی ہے۔'},

    {'image': 'data/raw/newspaper/img021.jpg', 'text': 'ثالثوں کی جانب سے مذاکرات کی بحالی کے لیے سفارتی کوششوں کی اطلاعات بھی سامنے آئی ہیں۔'},
    {'image': 'data/raw/newspaper/img022.jpg', 'text': 'بلوچستان کے ضلع چاغی میں نامعلوم مسلح افراد نے پانچ گیس باؤزر ٹرک نذرآتش کر دیے'},
    {'image': 'data/raw/synthetic/img023.jpg', 'text': 'عامر'},
    {'image': 'data/raw/synthetic/img024.jpg', 'text': 'متقدمة'},
    {'image': 'data/raw/synthetic/img025.jpg', 'text': 'رهيفه'},
    {'image': 'data/raw/books/img026.jpg', 'text': 'عمَّ يتساءَلون'},
    {'image': 'data/raw/books/img027.jpg', 'text': 'لا تقنطوا'},
    {'image': 'data/raw/books/img028.jpg', 'text': 'واللّٰہ'},
    {'image': 'data/raw/books/img029.jpg', 'text': 'أثيم'},
    {'image': 'data/raw/books/img030.jpg', 'text': 'لا يُحب'},
    {'image': 'data/raw/books/img031.jpg', 'text': 'وأفوّض'},
    {'image': 'data/raw/books/img032.jpg', 'text': 'إلى اللّٰہ'},
    {'image': 'data/raw/books/img033.jpg', 'text': 'ما يقولون'},
    {'image': 'data/raw/other/img034.jpg', 'text': 'جو لوگ صبر سے کام لیتے ہیں، ان کا ثواب انہیں بے حساب دیا جائے گا۔'},
    {'image': 'data/raw/other/img035.jpg', 'text': 'بیشک اللہ توکل کرنے والوں سے محبت فرماتا ہے۔'},
    {'image': 'data/raw/newspaper/img036.jpg', 'text': 'حالیہ ٹیکس ریفنڈ کے بعد ایپسٹین کے باقی اثاثوں کی مالیت اب 120 سے 150 ملین ڈالرز کے درمیان بتائی جا رہی ہے۔'},
    {'image': 'data/raw/other/img037.jpg', 'text': 'ہر چیز جو زمین پر ہے فنا ہو جانے والی ہے۔'},
    {'image': 'data/raw/newspaper/img038.jpg', 'text': 'حالیہ عدالتی ریکارڈز سے معلوم ہوا ہے کہ کرینا شولیاک کو اس ٹرسٹ کی بڑی شخصیات میں شامل کیا گیا تھا۔'},
    {'image': 'data/raw/newspaper/img039.jpg', 'text': 'بعض تصاویر میں امریکی صدر نے خود کو اور امریکہ کو دنیا کا محافظ قرار دیا ہے جو دنیا کو ایران سے بچانے میں مصروف ہے۔'},
    {'image': 'data/raw/newspaper/img040.jpg', 'text': 'ٹرمپ نے امریکی اسلحے کے ذخائر میں کمی کی خبروں کو مسترد کر دیا۔'},
    {'image': 'data/raw/other/img041.jpg', 'text': 'منزلیں بہادروں کا استقبال کرتی ہیں'},
    {'image': 'data/raw/other/img042.jpg', 'text': 'دائرے میں گھومنے والوں کو کبھی منزل نہیں'},
    {'image': 'data/raw/other/img043.jpg', 'text': 'بڑی خوبصورت ہیں آنکھیں تمہاری ہم جیسے کتنے ہی ڈوبے ان میں'},
    {'image': 'data/raw/other/img044.jpg', 'text': 'یہ نہ ہو کہ دھند میں کوئی گاڑی تمہارے اوپر سے گزر جائے۔'},
    {'image': 'data/raw/synthetic/img045.jpg', 'text': 'پاکستانی نستعلیق کا صحیح اور معیاری فونٹ'},
    {'image': 'data/raw/synthetic/img046.jpg', 'text': 'ساغرِ جم سے میرا جامِ سفال اچھا'},
    {'image': 'data/raw/synthetic/img047.jpg', 'text': 'جھیل ہے کہ ساغر ہے یہ چشمِ فتن سمندر بھی کتنے ہوئے غرقاب ان میں'},
    {'image': 'data/raw/synthetic/img048.jpg', 'text': 'اردو ایک پیاری زبان ہے'},
    {'image': 'data/raw/synthetic/img049.jpg', 'text': 'اور بازار سے لے آئے اگر ٹوٹ گیا'},
    {'image': 'data/raw/other/img050.jpg', 'text': 'ہیں جو کبھی گلزار تھیں اور اب محض ایک اجاڑ بستی کا منظر پیش کرتی ہیں۔'},
    {'image': 'data/raw/signboards/img051.jpg', 'text': 'داخلہ جاری ہے'},
    {'image': 'data/raw/synthetic/img052.jpg', 'text': 'ہفتہ'},
    {'image': 'data/raw/synthetic/img053.jpg', 'text': 'نفیس پاکستانی ویب نسخ فانٹ'},
    {'image': 'data/raw/other/img054.jpg', 'text': 'ادھار مانگ کر شرمندہ نہ کریں۔'},
    {'image': 'data/raw/synthetic/img055.jpg', 'text': 'اب اپنے آپ سے بھی چھُپ گئی ہے'},
    {'image': 'data/raw/other/img056.jpg', 'text': 'نیکی کی باتیں ہی کرتے کبھی کسی کا دل نہ دکھاتے'},
    {'image': 'data/raw/other/img057.jpg', 'text': 'پریت کا وعدہ کر کے پیا نے پریت نبھانا چھوڑ دیا مہرنے اکھیاں پھیر لیں دم دم کا سانا چھوڑ دیا'},
    {'image': 'data/raw/other/img058.jpg', 'text': 'زندگی کی راہوں میں رنج و غم کے میلے ہیں بھیڑ ہے قیامت کی پھر بھی ہم اکیلے ہیں'},
    {'image': 'data/raw/signboards/img059.jpg', 'text': 'خاموش رہو'},
    {'image': 'data/raw/books/img060.jpg', 'text': 'چار برہمنوں میں گہری دوستی تھی۔'},

    {'image': 'data/raw/signboards/img061.jpg', 'text': 'میری مرضی'},
    {'image': 'data/raw/signboards/img062.jpg', 'text': 'یار تنگ نہ کر'},
    {'image': 'data/raw/signboards/img063.jpg', 'text': 'زیادہ فری نہ ہو'},
    {'image': 'data/raw/other/img064.jpg', 'text': 'شرم کی کشش حُسن سے زیادہ ہوتی ہے۔'},
    {'image': 'data/raw/other/img065.jpg', 'text': 'مخلص لوگ چونکہ بناوٹ سے دور ہوتے ہیں'},
    {'image': 'data/raw/signboards/img066.jpg', 'text': 'قضول بیٹھنا منع ہے'},
    {'image': 'data/raw/other/img067.jpg', 'text': 'خوش قسمت ہوتے ہیں'},
    {'image': 'data/raw/synthetic/img068.jpg', 'text': 'تہجد'},
    {'image': 'data/raw/other/img069.jpg', 'text': 'آپ جا سکتے ہیں۔'},
    {'image': 'data/raw/synthetic/img070.jpg', 'text': 'بہترین صبر'},
    {'image': 'data/raw/other/img071.jpg', 'text': 'ہر دن نیا موقع ہے'},
    {'image': 'data/raw/other/img072.jpg', 'text': 'تقدیر بدل جائے گی راتوں کو اُٹھ'},
    {'image': 'data/raw/other/img073.jpg', 'text': 'تماشہ یہ تھا کہ تماشائی اپنے تھے'},
    {'image': 'data/raw/other/img074.jpg', 'text': 'سب کو سب نہیں ملتا۔'},
    {'image': 'data/raw/other/img075.jpg', 'text': 'کون سیکھا ہے صرف باتوں سے سب کو ایک حادثہ ضروری ہے'},
    {'image': 'data/raw/other/img076.jpg', 'text': 'الفاظ کم، عمل زیادہ'},
    {'image': 'data/raw/other/img077.jpg', 'text': 'ہم کہاں جائیں سادگی لے کر'},
    {'image': 'data/raw/other/img078.jpg', 'text': 'بھلا دوسری بارش میں مٹی مہکتی ہے کبھی'},
    {'image': 'data/raw/other/img079.jpg', 'text': 'وہ احساس ہی کیا جو دلایا جائے'},
    {'image': 'data/raw/other/img080.jpg', 'text': 'دل بیزار ہے دنیا کی فریبی رونقوں سے!'},

    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_42_07_PM.jpeg',
     'text': 'مشکل ہے۔'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_42_28_PM.jpeg',
     'text': 'صنعتی گاڑیوں کا داخلہ ممنوع ہے'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_44_31_PM.jpeg',
     'text': 'سراب'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_44_45_PM.jpeg',
     'text': 'عربی گرامر'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_44_58_PM.jpeg',
     'text': 'قرآن مجید'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_49_52_PM.jpeg',
     'text': 'خدا'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_50_02_PM.jpeg',
     'text': 'اردو کے بہترین شخصی خاکے'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_12_52_36_PM.jpeg',
     'text': 'المر'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_01_PM__2_.jpeg',
     'text': 'اور اختتام یہ کہ دل اب کچھ نہیں چاہتا۔'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_01_PM.jpeg',
     'text': 'آزمائے گئے ہو تو نوازے بھی جاؤ گے'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_02_PM__1_.jpeg',
     'text': 'تکلیف بتانے میں بھی تکلیف ہوتی ہے۔'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_02_PM__2_.jpeg',
     'text': 'میں اپنی ہی الجھی ہوئی راہوں کا تماشا ہوں'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_02_PM.jpeg',
     'text': 'ہر پسندیدہ چیز خوشی نہیں دیتی'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_03_PM__1_.jpeg',
     'text': 'دھول جتنی بھی اونچی ہو جائے آسمان کو گندہ نہیں کر سکتی'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_03_PM__2_.jpeg',
     'text': 'ہم صورت گر کچھ خوابوں کے'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_03_PM.jpeg',
     'text': 'میں نے حقیقت سے زیادہ کسی چیز کو تلخ نہیں پایا'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_04_PM__1_.jpeg',
     'text': 'بس اگلے موڑ سکون ہو گا چل زندگی تھوڑا اور چلیں'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_04_PM__2_.jpeg',
     'text': 'خوب ہوتی ہے گفتگو تم سے، تم سے جب گفتگو نہیں ہوتی'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_04_PM.jpeg',
     'text': 'نہیں نگاہ میں میری غزل، تو جستجو ہی سہی۔'},
    {'image': 'data/raw/newspaper/WhatsApp_Image_2026-07-27_at_2_18_05_PM.jpeg',
     'text': 'مجھ سے پہلی سی محبت مری محبوب نہ مانگ'},
]

with open('data/labels.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=['image', 'text'])
    writer.writeheader()
    writer.writerows(labels)

print(f'Labels file created with {len(labels)} entries')
# Out:
# Labels file created with 200 entries

# %%
import os

os.listdir('/content')
# Out:
# ['.config', 'drive', 'data', 'sample_data']

# %%
from google.colab import files

files.download('/content/data/labels.csv')
